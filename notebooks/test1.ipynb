# %%
import pandas as pd
import numpy as np
data = {
'Patient_ID': [101, 102, 103, 104, 105],
'Age': [25, 30, np. nan, 45, 22],
'Tension': [12, np.nan, 14, 15, np. nan],
' Fumeur': ['Oui', 'Non', 'Non', np. nan,
" Oui "]
}
df = pd. DataFrame (data)
# 1. Detection globale
print (df. isnull ().sum ())
# 2. Imputation de l'Age par la moyenne
df ['Age'] = df ['Age']. fillna (df ['Age']. mean ())
# Out:
#   Cell In[2], line 4
#     url = "https://books.com'
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
import requests
from bs4 import BeautifulSoup 
import time
# URL de test dediee a l'apprentissage
url = "https://www.scrapethissite.com/pages/simple/"
response = requests.get (url)

if response. status_code == 200:
      soup = BeautifulSoup (response.text, 'html.parser')
      # Extraction des noms de pays (Balise h3 avec classe specifique)
      countries = soup. find_all('h3', class_='country-name')
      print ("---Echantillonudesudonneesucollecteesu---")
      for country in countries [:5]:
            print (f"Paysu:u{country.text.strip()}")
else :
      print (f"Echecudeul' acquisition. Codeud' erreuru: {response.status_code}")
# Out:
# ---Echantillonudesudonneesucollecteesu---
# Paysu:uAndorra
# Paysu:uUnited Arab Emirates
# Paysu:uAfghanistan
# Paysu:uAntigua and Barbuda
# Paysu:uAnguilla
